# %% [markdown]
# ### Introduction to Jupyter Notebook
# mcq

# %% [markdown]
# 1st question:
# Monospace Fonts
# Surrounding the text with which of the following elements will give you the monospace font in a markdown cell?
#
#
# Single quotation marks (‘)
#
#
# Double quotation marks (“)
#
#
# Back single quotation marks (`) = answer
#
# ✓ Correct
# Feedback:
# A back single quotation mark (`) on either side of the text converts it into monospace.
#
#
# The dollar sign ($)

# %% [markdown]
# 2nd question:
# upyter Notebook Commands
# Which of the following commands will execute the current cell and move the navigator to the next cell?
#
#
# Enter
#
#
# Shift + Enter = answer
#
# ✓ Correct
# Feedback:
# Shift + Enter executes the current cell and moves the navigator to the next cell.
#
#
# Ctrl/Cmd + Enter
#
#
# Tab + Enter

# %% [markdown]
# ### Data Types in Python
# mcq

# %% [markdown]
# 1st question:
# Float to Int; Back to Float!
# What would be the output of the following code?
#
# x = 3.5
# print(float(int(x)))
#
#
#
# 3.5
#
#
# 3.0 = answer
#
# ✓ Correct
# Feedback:
# The int(x) will convert the float value(3.5) to an integer value 3, and then float(3) will return the value 3.0.
#
#
# 3
#
#
# Error

# %% [markdown]
# 2nd question:
# What's Your Datatype?
# What would be the output of the code given below?
#
# name = Varma
#
# print(type(name))
#
#
#
# <class 'str'>
#
#
# str
#
#
# String
#
#
# Error = answer
#
# ✓ Correct
# Feedback:
# The above piece of code throws an error saying 'invalid syntax' because Varma isn’t properly declared as a string. During the execution of the code, it will be considered as two variables (name, Varma) being equated, and since they are not declared earlier, the compiler throws an error.

# %% [markdown]
# ### Arithmetic Operations
# mcq

# %% [markdown]
# 1st question:
# Will this Run?
# What would be the output of the following code?
#
# x = 3
# y = 2.5
# z = 5
# print(X + y / z)
#
#
#
# 5.5
#
#
# 1.1
#
#
# 3.5
#
#
# Error = answer
#
# ✓ Correct
# Feedback:
# The above code throws an error since variable 'X' is not defined in the code but is being used in the final print statement.
#
#
#
# Note: Be careful with these type of errors while practising Python coding.

# %% [markdown]
# 2nd question:
# Operator No. 1
# Follow the operator precedence rule in Python and provide the output of the following expression:
#
# https://docs.python.org/3.7/reference/expressions.html#operator-precedence
#
# 4 % (1 + 9)**2 - 60 // (7 + 2)
#
#
#
# 10
#
#
# 75
#
#
# -2 = answer
#
#
# Error

# %% [markdown]
# ### String Operations

# %% [markdown]
# 1st question:
# I Love Python!
# How will you extract Python from the string word "I love Python programming"? (More than one options may be correct.)
#
# word[7:13]
#
# ✓ Correct
#
# word[7:12]
#
# ✕ Incorrect
#
# word[-12:-18]
#
# ✕ Incorrect
#
# word[-18:-12]
#
# ✓ Correct

# %%
2nd question:
Operations on Strings?!
The len() function in Python returns the length of the string when a string is passed as an argument. For example, len(‘Python’) would return an integer value 6.

With this in mind, what would be the output of the following code?

x = 'len'
x[len(x * 2) - 5]
 


'n'


''


'e' ✓ Correct answer


Error

# %% [markdown]
# ### 1st codig question:
# String Problem
# Description
# In a certain encrypted message which has information about the location(area, city), the characters are jumbled such that first character of the first word is followed by the first character of the second word, then it is followed by second character of the first word and so on
#
# In other words, let’s say the location is bandra,mumbai
#
# The encrypted message says ‘bmaunmdbraai’.
#
# Sample Input:
#
# bmaunmdbraai
#
#
# Sample Output:
#
# bandra,mumbai
#
# Let’s say the size or length of the two words wouldn’t match then the smaller word is appended with # and then encrypted in the above format.
#
# With this in mind write a code to identify the right location and print it as place,city.

# %% [markdown]
# import ast,sys
# input_str = sys.stdin.read()
# message1 = input_str[0:-1:2]
# message2 = input_str[1:len(input_str):2]
# print(message1.strip('#') + "," + message2.strip('#'))

# %% [markdown]
# ### Practice Questions mcq

# %% [markdown]
# 1st question:
# Long Strings
# Calculate the number of characters in the string.
#
#
# 193   ✓ Correct answer
#
#
# 200
#
#
# 300
#
#
# 500

# %% [markdown]
# 2nd question:
# 'a' minor String
# Count the number of occurrences of 'a' in the string.
#
#
# 1
#
#
# 2    ✓ Correct answer
#
# 10
#
#
# 5

# %% [markdown]
# 3rd question:
# If Only
# Identify whether the string starts with 'if'.
#
#
# False   ✓ Correct answer
#
# True

# %% [markdown]
# 4th question:
# No Strings Attached
# Return the substring starting at index 63 and ending at index 88 [Both the indexes are inclusive].
#
#
# 'OQYWFClFhFGA'
#
#
# 'mCfgDYqbaBHAUvIWhMnvwZnEMV'   ✓ Correct answer
#
# 'IWYwGKpmZhnJiyzTslSIhSwv'
#
#
# 'JMEphzmifTkyqOMNpnOtXZ'

# %% [markdown]
# 5th question:
# 46th Character
# Identify the 46th character in the string.
#
#
# a
#
#
# b
#
#
# z   ✓ Correct answer
#
#
# x

# %% [markdown]
# ### Practice Questions - I

# %%
1st:
Data Types in Python:
What will be the output of the following code snippet?

number='159'

print(type(number))

answer: 
    
<class ‘str’>

✓ Correct
Feedback:
Correct! The numbers are treated as string data type because they are written inside quotes.

# %% [markdown]
# 2nd:
# Data Types in Python:
# What will be the output of the following code snippet?
#
# number=34.721
# print(float(int(number)))
#
# anser:
#
#
# 34.0
#
# ✓ Correct
# Feedback:
# Correct! int(number) will return 34 and float(34) will return 34.0.

# %% [markdown]
# 3rd:
# Data Types in Python:
# What will be the output of the following code snippet?
#
# name = Alex
# print(type(name))
#
# answer:
#
# Compilation error
#
# ✓ Correct
# Feedback:
# Correct! The string is not defined properly. A string should always be defined inside single or double-quotes.

# %% [markdown]
# 4th:
# Arithmetic operations:
# What will be the output of the following code snippet?
#
# a = 8.9
# b = 2
# c = 5
# print(a//b//c)
#
#
# answer :   0.0
#
# ✓ Correct
# Feedback:
# Correct! The operator ‘//’ performs the following floor division:
# 8.9//2//5 = 4.0//5=0.0

# %% [markdown]
# 5th:
# Arithmetic operations:
# What is the output of the following expression?
#
# 4 // 8 + ( 2.5 + 7.5 ) - 6 * 3
#
# answer :
#
# -8.0
#
# ✓ Correct
# Feedback:
# This is the correct answer.
# Steps:
# 4 // 8 + (2.5 + 7.5) -6 * 3
# 4 // 8 + 10 - 6 * 3
# 0 +10 - 6 * 3
# 0 + 10 - 18
# 10 - 18
# -8

# %% [markdown]
# 6th:
# Arithmetic operations:
# What will be the output of the following expression?
#
# 5 % ( 2 + 12 ) ** 3 - 60 // ( 7 + 1 ) * 2
#
# answer :
#
# -9
#
# ✓ Correct
# Feedback:
# This is the correct answer.
# Steps
# 5 % 2774 -60 // 8 *2
# 5 - 60 // 8 * 2
# 5 - 7 * 2
# 5 - 14 = -9

# %% [markdown]
# 7th:
# String operations
# What will be the output of the following code snippet?
#
# string_1 = "I love to code in python"
# print( string_1[7:13])
#
# answer :
#
# to cod
#
# ✓ Correct
# Feedback:
# In this slicing, the 7th index will be included and 13th index will be excluded.

# %% [markdown]
# 8th:
# String operations
# What is the code to extract “split” from the given string?
#
# sentence = 'This sentence needs to be split into words'
#
# answer :
#
# a. sentence[-16:-11]
#
#
# b. sentence[-17:-11]
#
#
# c. print(sentence.split()[5])
#
#
# d. Both a and c = answer
#
# ✓ Correct
# Feedback:
# Both the slicing using indexes and the split() function will give you the desired result. However, using the split() function is much easier than indexing.

# %% [markdown]
# 9th:
# String operations
# What will be the output of the following code snippet?
#
# len = 'python'
# print(len(len))
#
# answer :
#
# Error
#
# ✓ Correct
# Feedback:
# Correct! ‘len’ is a keyword. keywords cannot be used as variable names.

# %% [markdown]
# 10th:
# Control Structures and Functions in Python
# Identify the error in the following code fragment:
#
# x=10
# if x%2==0
# print("even number")
# else
# print("odd number")
#
# answer :
#
# a. Indentation error
#
#
# b. Syntax Error
#
#
# c. No Error
#
#
# d. Both a and b = answer
#
# ✓ Correct
# Feedback:
# Correct! The colon is missing in both the if-else statements, and the print statements are not indented properly. These two are the important things to be considered while using an if-else statement.

# %% [markdown]
# 11th:
# Control Structures and Functions in Python
# What will be the output of the following code?
#
# if 4+9<10:
#   print("true")
# else:
#   print("false")
# print("true")
#
# answer :
#
# false   ✓ Correct answer
#
# true    ✓ Correct answer

# %% [markdown]
# 12th:
# Control Structures and Functions in Python
#  Consider the following code snippet:
#
# if x>50:
#   if x>90:
#     print("excellent")
#   else:
#     if x>80:
#       print("good")
#     else:
#       print("fair")
# else:
#   if x>30:
#     print("average")
#   else:
#     print("poor")
#
# answer :
#
# fair
#
# ✓ Correct answer

# %% [markdown]
# 13th:
# Control Structures and Functions in Python
# What will be output of the following code snippet?
#
# a='pqrstuv'
# i='j'
# while i in a:
#   print(i)
#
# answer :
#
# No output
#
# ✓ Correct answer

# %% [markdown]
# 14th:
# Control Structures and Functions in Python
# What will be the output of the following code snippet?
#
# i = 16
# while False:
#     if i%2 == 0:
#         break
#     print(i)
#     i += 2
#
# answer :
#
# No output
#
# ✓ Correct answer

# %% [markdown]
# 15th:
# String updation
# What will be the output of the following code?
#
# s="Upgrad"
#
# for i in range(len(s)):
#     if s[i] in 'a':
#         s[i]='*'
#
# print(s)
#
# answer :
#
# Error
#
# ✓ Correct answer

# %% [markdown]
# ### Practice Questions - II

# %% [markdown]
# Digit or Alphabet
# Description
# Write a program to display whether the input is a digit or a letter of the alphabet.
#
# ----------------------------------------------------------------------
#
# Input:
#
# A digit or a letter of the alphabet
#
# Output:
#
# Displays whether the given output is an integer or a letter of the alphabet
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# 1
#
#
#
# Sample output:
#
# Integer

# %% [markdown]
# x=input()
#
# if x.isalpha():
#
#     print("Alphabet")
#
# elif x.isdigit():
#
#     print("Integer")

# %% [markdown]
# ASCII values
# Description
# Write a program to accept a character and display its next and previous character.
#
#
# ----------------------------------------------------------------------
#
# Input:
#
# A character
#
# Output:
#
#
# -------------------------------------------------------------------
#
# Sample input:
#
# D
#
# Sample output:
#
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# 8
#
# Sample output:
#
# 7
#
# 9

# %% [markdown]
# inp=input()
# print(chr(ord(inp)-1))
# print(chr(ord(inp)+1))

# %% [markdown]
# No Vowels
# Description
# Write a program to accept a string from the user, delete all vowels from the string and display the result.
#
# ----------------------------------------------------------------------
#
# Input:
#
# A string
#
# Output:
#
# A string with vowels removed
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# Upgrad
#
# Sample output:
#
# pgrd

# %% [markdown]
# #Take input
# s=input()
#
# #Creating an empty string that will store the modified string
# s_new=''
#
# #Looping the string 's' and extracting only the consonants
# for i in range(len(s)):
#     if s[i] not in "AIEOUaeiou":
#         s_new=s_new+s[i]
#
# #Print the result
#
# print(s_new)

# %% [markdown]
# Description
# Write a program to accept three sides of a triangle as the input and print whether the triangle is valid or not.
#
# (A triangle is valid if the sum of any two sides is greater than the third side.)
#
#
# ----------------------------------------------------------------------
#
# Input:
#
# Three sides of a triangle separated by a space
#
# Output:
#
# Whether the given triangle is "Valid" or "Invalid"
#
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# 3 4 5
#
# Sample output:
#
# Valid

# %% [markdown]
# a,b,c=input().split()
#
# d = int(a)
#
# e = int(b)
#
# f = int(c)
#
# if d+e>f or e+f>d or d+f>e:
#     print('Valid')
# else:
#
#     print('Invalid')

# %% [markdown]
# ### Practice Questions - III

# %% [markdown]
# Description
# Write a program to display the multiplication table of a given number.
#
#
#
# ----------------------------------------------------------------------
#
# Input:
#
# A positive integer
#
#
#
# Output:
#
# Multiplication table
#
#
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# 5
#
#
#
# Sample output:
#
# 5 * 1 = 5
#
# 5 * 2 = 10
#
# 5 * 3 = 15
#
# 5 * 4 = 20
#
# 5 * 5 = 25
#
# 5 * 6 = 30
#
# 5 * 7 = 35
#
# 5 * 8 = 40
#
# 5 * 9 = 45
#
# 5 * 10 = 50

# %% [markdown]
# num = int(input())
# for i in range(1,11):
#     print (num,'*',i,'=',num*i)

# %% [markdown]
# Character frequency
# Description
# Write a program to accept a string value from the user and accept a char value from the user and find out the total occurrence of the char value in the string value. Note that the count is not case-sensitive
#
# ----------------------------------------------------------------------
#
# Input:
#
# A string and a character whose occurrence is to be found
#
#
# Output:
#
# An integer
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# Python Programming
#
# P
#
#
# Sample output:
#
# 2

# %% [markdown]
# input_string=input()
# input_char=input()
# print(input_string.lower().count(input_char.lower()))

# %% [markdown]
# Sum of digits
# Description
# Write a program to calculate the sum of the digits of a given number
#
# ----------------------------------------------------------------------
#
# Input:
#
# An n digit number
#
# Output:
#
# Sum of the digits
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# 983
#
# Sample output:
#
# 20

# %% [markdown]
# n=int(input())
# tot=0
# while(n>0):
#     dig=n%10
#     tot=tot+dig
#     n=n//10
# print(tot)

# %% [markdown]
# Count the digits
# Description
# Write a program to accept a number from the user and count the zeros, odd digits and non-zero even digits from the entered number.
#
# ----------------------------------------------------------------------
#
# Input:
#
# A positive integer of n digits
#
# Output:
#
# Three integers representing the occurrences of zeros, odd digits and non-zero even digits from the entered number.
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# 1030
#
# Sample output:
#
# Number of odd digits: 2
#
# Number of non-zero even digits: 0
#
# Number of zeros: 2

# %% [markdown]
# #Take input
# n=int(input())
#
# #write your code here
# count_of_zero = 0
# count_of_odd = 0
# count_of_even = 0
#
# for count in str(n):
#     count = int(count)
#     if count == 0:
#         count_of_zero += 1
#     elif count % 2 == 0:
#         count_of_even += 1
#     elif count % 2 != 0:
#         count_of_odd += 1
# print('Number of odd digits:',count_of_odd)
# print('Number of non-zero even digits:',count_of_even)
# print('Number of zeros:',count_of_zero)

# %% [markdown]
# String manipulation
# Description
# Write a program that takes a string as the input and does the following:
#
#     -Removes the numbers, special characters
#
#     -Converts uppercase letters to lowercase letters, and vice versa
#
# ----------------------------------------------------------------------
#
# Input:
#
# A string
#
# Output:
#
# A string with numbers, special characters removed, upper and lower cases swapped
#
# ----------------------------------------------------------------------
#
# Sample input:
#
# Programming1234
#
# Sample output:
#
# pROGRAMMING

# %% [markdown]
# #Take input
# input_string=input()
#
# #Initialising an empty string that will store the modified resultant string
# new_str=''
#
# #looping through the input_string where 'c' is each character of the string
# for c in input_string:
#
#     # if the character 'c' is an alphabet, implement the code following otherwise skip that character and go for next iteration
#     if (c.isalpha()):
#
#         # if the character 'c' is an uppercase, convert it into lowercase otherwise convert the character into uppercase
#         if c.isupper():
#             new_str=new_str+c.lower()
#         else:
#             new_str=new_str+c.upper()
#
#
# print(new_str)
